# %%
import pandas as pd
from matplotlib import pyplot as plt
# Out:
#                            Entity Code  Year  RuralElectricity  \
# 0    Democratic Republic of Congo  COD  2018          1.000000
# 1               Equatorial Guinea  GNQ  2018          1.962391
# 2                            Chad  TCD  2018          2.308083
# 3        Central African Republic  CAF  2018          2.528976
# 4                           Haiti  HTI  2018          2.972568
# ..                            ...  ...   ...               ...
# 217                       Vietnam  VNM  2018        100.000000
# 218                  Burkina Faso  BFA  2018               NaN
# 219                         Libya  LBY  2018               NaN
# 220                    Mauritania  MRT  2018               NaN
# 221                         Nauru  NRU  2018               NaN
#
#      UrbanElectricity  Continent
# 0           40.514824        NaN
# 1           91.354973        NaN
# 2           36.160191        NaN
# 3           32.297379        NaN
# 4           78.933670        NaN
# ...

# %%
df = pd.read_csv("RuralvsUrban2018.csv")
df

# %%
df1= df[:30]

df1.set_index('Entity',inplace=True)
ax1 = df1[['RuralElectricity', 'UrbanElectricity']].plot(kind='bar', figsize=(10, 6))
ax1.set_title('Access to Electricity in Rural and Urban Areas(2018)')

plt.xticks(rotation=90)
plt.show()

# %%
df2= df[30:60]

df2.set_index('Entity',inplace=True)
ax2 = df2[['RuralElectricity', 'UrbanElectricity']].plot(kind='bar', figsize=(10, 6))
ax2.set_title('Access to Electricity in Rural and Urban Areas(2018)')

plt.xticks(rotation=90)
plt.show()

# %%
df = pd.read_csv("RuralvsUrban2019.csv")
df

df1= df[:30]

df1.set_index('Entity',inplace=True)
ax1 = df1[['RuralAccess', 'UrbanAccess']].plot(kind='bar', figsize=(10, 6))
ax1.set_title('Access to Electricity in Rural and Urban Areas(2019)')

plt.xticks(rotation=90)
plt.show()

# %%
df2= df[30:60]

df2.set_index('Entity',inplace=True)
ax2 = df2[['RuralAccess', 'UrbanAccess']].plot(kind='bar', figsize=(10, 6))
ax2.set_title('Access to Electricity in Rural and Urban Areas(2019)')

plt.xticks(rotation=90)
plt.show()

# %%
df = pd.read_csv("RuralvsUrban2020.csv")
df
# Out:
#                            Entity Code  Year  RuralAccess  UrbanAccess  \
# 0               Equatorial Guinea  GNQ  2020     0.932630    90.966965
# 1    Democratic Republic of Congo  COD  2020     1.000000    40.659931
# 2                            Chad  TCD  2020     1.994306    40.624454
# 3                           Haiti  HTI  2020     2.200197    80.544746
# 4        Central African Republic  CAF  2020     2.252867    33.562920
# ..                            ...  ...   ...          ...          ...
# 217                    Uzbekistan  UZB  2020   100.000000   100.000000
# 218                        Angola  AGO  2020          NaN    73.708916
# 219                  Burkina Faso  BFA  2020          NaN    65.753906
# 220                         Libya  LBY  2020          NaN   100.000000
# 221                    Mauritania  MRT  2020          NaN    88.374878
#
#      Continent
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# ...

# %%
df1= df[:30]

df1.set_index('Entity',inplace=True)
ax1 = df1[['RuralAccess', 'UrbanAccess']].plot(kind='bar', figsize=(10, 6))
ax1.set_title('Access to Electricity in Rural and Urban Areas(2020)')

plt.xticks(rotation=90)
plt.show()

# %%
df2= df[30:60]

df2.set_index('Entity',inplace=True)
ax2 = df2[['RuralAccess', 'UrbanAccess']].plot(kind='bar', figsize=(10, 6))
ax2.set_title('Access to Electricity in Rural and Urban Areas(2020)')

plt.xticks(rotation=90)
plt.show()
