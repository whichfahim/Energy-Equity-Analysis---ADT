# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('datasets/data.csv')

# %%
df.head()
# Out:
#         Entity code  Year  Access to electricity (% of population)
# 0  Afghanistan  AFG  2000                                 1.613591
# 1  Afghanistan  AFG  2001                                 4.074574
# 2  Afghanistan  AFG  2002                                 9.409158
# 3  Afghanistan  AFG  2003                                14.738506
# 4  Afghanistan  AFG  2004                                20.064968

# %%
df2 = pd.read_csv('datasets/DEMO_DS.csv')

# %%
display(df2)
# Out:
#              DEMO_IND                                 Indicator LOCATION  \
# 0      SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 1      SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 2      SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 3      SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 4      SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# ...               ...                                       ...      ...
# 41386  SP_DYN_LE00_IN   Life expectancy at birth, total (years)      GIB
# 41387  SP_DYN_LE00_IN   Life expectancy at birth, total (years)      GIB
# 41388  SP_DYN_LE00_IN   Life expectancy at birth, total (years)      GIB
# 41389  SP_DYN_LE00_IN   Life expectancy at birth, total (years)      GIB
# 41390  SP_DYN_LE00_IN   Life expectancy at birth, total (years)      GIB
#
#          Country  TIME  Time  Value Flag Codes Flags
# ...

# %%
df2.rename(columns={'Time': 'Year'}, inplace=True)
df2.head()
# Out:
#          DEMO_IND                                 Indicator LOCATION  \
# 0  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 1  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 2  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 3  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 4  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
#
#      Country  TIME  Year  Value Flag Codes Flags
# 0  Australia  2016  2016    1.8        NaN   NaN
# 1  Australia  2017  2017    1.7        NaN   NaN
# 2  Australia  2018  2018    1.7        NaN   NaN
# 3  Australia  2019  2019    1.7        NaN   NaN
# 4  Australia  2020  2020    1.6        NaN   NaN

# %%
df2 = df2.drop('TIME', axis=1)

# %%
df2.rename(columns={'LOCATION': 'code'}, inplace=True)
df2.head()
# Out:
#          DEMO_IND                                 Indicator code    Country  \
# 0  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)  AUS  Australia
# 1  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)  AUS  Australia
# 2  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)  AUS  Australia
# 3  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)  AUS  Australia
# 4  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)  AUS  Australia
#
#    Year  Value Flag Codes Flags
# 0  2016    1.8        NaN   NaN
# 1  2017    1.7        NaN   NaN
# 2  2018    1.7        NaN   NaN
# 3  2019    1.7        NaN   NaN
# 4  2020    1.6        NaN   NaN

# %%
df.rename(columns={'Code':'code'}, inplace=True)

# %%
df.head()
# Out:
#         Entity code  Year  Access to electricity (% of population)
# 0  Afghanistan  AFG  2000                                 1.613591
# 1  Afghanistan  AFG  2001                                 4.074574
# 2  Afghanistan  AFG  2002                                 9.409158
# 3  Afghanistan  AFG  2003                                14.738506
# 4  Afghanistan  AFG  2004                                20.064968

# %%
df2.head()
# Out:
#          DEMO_IND                                 Indicator code    Country  \
# 0  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)  AUS  Australia
# 1  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)  AUS  Australia
# 2  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)  AUS  Australia
# 3  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)  AUS  Australia
# 4  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)  AUS  Australia
#
#    Year  Value Flag Codes Flags
# 0  2016    1.8        NaN   NaN
# 1  2017    1.7        NaN   NaN
# 2  2018    1.7        NaN   NaN
# 3  2019    1.7        NaN   NaN
# 4  2020    1.6        NaN   NaN

# %%
result = pd.merge(df, df2, on=["code", "Year"], how="left")
result.head()
# Out:
#         Entity code  Year  Access to electricity (% of population) DEMO_IND  \
# 0  Afghanistan  AFG  2000                                 1.613591      NaN
# 1  Afghanistan  AFG  2001                                 4.074574      NaN
# 2  Afghanistan  AFG  2002                                 9.409158      NaN
# 3  Afghanistan  AFG  2003                                14.738506      NaN
# 4  Afghanistan  AFG  2004                                20.064968      NaN
#
#   Indicator Country  Value Flag Codes Flags
# 0       NaN     NaN    NaN        NaN   NaN
# 1       NaN     NaN    NaN        NaN   NaN
# 2       NaN     NaN    NaN        NaN   NaN
# 3       NaN     NaN    NaN        NaN   NaN
# 4       NaN     NaN    NaN        NaN   NaN

# %%
display(result)
# Out:
#             Entity code  Year  Access to electricity (% of population)  \
# 0      Afghanistan  AFG  2000                                 1.613591
# 1      Afghanistan  AFG  2001                                 4.074574
# 2      Afghanistan  AFG  2002                                 9.409158
# 3      Afghanistan  AFG  2003                                14.738506
# 4      Afghanistan  AFG  2004                                20.064968
# ...            ...  ...   ...                                      ...
# 38577     Zimbabwe  ZWE  2020                                52.747670
# 38578     Zimbabwe  ZWE  2020                                52.747670
# 38579     Zimbabwe  ZWE  2020                                52.747670
# 38580     Zimbabwe  ZWE  2020                                52.747670
# 38581     Zimbabwe  ZWE  2020                                52.747670
#
#              DEMO_IND                                          Indicator  \
# ...

# %%
result = result.drop('Country', axis=1)
result.head()
# Out:
#         Entity code  Year  Access to electricity (% of population) DEMO_IND  \
# 0  Afghanistan  AFG  2000                                 1.613591      NaN
# 1  Afghanistan  AFG  2001                                 4.074574      NaN
# 2  Afghanistan  AFG  2002                                 9.409158      NaN
# 3  Afghanistan  AFG  2003                                14.738506      NaN
# 4  Afghanistan  AFG  2004                                20.064968      NaN
#
#   Indicator  Value Flag Codes Flags
# 0       NaN    NaN        NaN   NaN
# 1       NaN    NaN        NaN   NaN
# 2       NaN    NaN        NaN   NaN
# 3       NaN    NaN        NaN   NaN
# 4       NaN    NaN        NaN   NaN

# %%
result = result.drop('DEMO_IND', axis=1)
result.head()
# Out:
#         Entity code  Year  Access to electricity (% of population) Indicator  \
# 0  Afghanistan  AFG  2000                                 1.613591       NaN
# 1  Afghanistan  AFG  2001                                 4.074574       NaN
# 2  Afghanistan  AFG  2002                                 9.409158       NaN
# 3  Afghanistan  AFG  2003                                14.738506       NaN
# 4  Afghanistan  AFG  2004                                20.064968       NaN
#
#    Value Flag Codes Flags
# 0    NaN        NaN   NaN
# 1    NaN        NaN   NaN
# 2    NaN        NaN   NaN
# 3    NaN        NaN   NaN
# 4    NaN        NaN   NaN

# %%
display(result)
# Out:
# Indicator  DEC alternative conversion factor (LCU per US$)  \
# code Year
# ABW  2016                                                1
#      2017                                                1
#      2018                                                1
#      2019                                                1
#      2020                                                1
# ...                                                    ...
# ZWE  2016                                                1
#      2017                                                1
#      2018                                                1
#      2019                                                1
#      2020                                                1
#
# Indicator  Fertility rate, total (births per woman)  GDP (constant LCU)  \
# code Year
# ABW  2016                                         1                   1
#      2017                                         1                   1
# ...

# %%
result = result[result.Year > 2015]

# %%
display(result)
# Out:
#             Entity code  Year  Access to electricity (% of population)  \
# 0      Afghanistan  AFG  2000                                 1.613591
# 1      Afghanistan  AFG  2001                                 4.074574
# 2      Afghanistan  AFG  2002                                 9.409158
# 3      Afghanistan  AFG  2003                                14.738506
# 4      Afghanistan  AFG  2004                                20.064968
# ...            ...  ...   ...                                      ...
# 38577     Zimbabwe  ZWE  2020                                52.747670
# 38578     Zimbabwe  ZWE  2020                                52.747670
# 38579     Zimbabwe  ZWE  2020                                52.747670
# 38580     Zimbabwe  ZWE  2020                                52.747670
# 38581     Zimbabwe  ZWE  2020                                52.747670
#
#              DEMO_IND                                          Indicator  \
# ...

# %%
result=pd.pivot_table(result,index=['code','Year','Access to electricity (% of population)'],columns='Indicator',values='Value',aggfunc=len,fill_value=0)

# %%
display(result)
# Out:
# Indicator                                          DEC alternative conversion factor (LCU per US$)  \
# code Year Access to electricity (% of population)
# ABW  2016 100.000000                                                                             1
#      2017 100.000000                                                                             1
#      2018 100.000000                                                                             1
#      2019 100.000000                                                                             1
#      2020 100.000000                                                                             1
# ...                                                                                            ...
# ZWE  2016 42.561730                                                                              1
#      2017 44.178635                                                                              1
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named df
# Replace 'Dependent_Column' and 'Independent_Column' with the actual column names in your DataFrame

# Plotting a scatter plot
plt.scatter(result['GDP (current US$)'], result['Access to electricity (% of population)'])

# Adding labels and title
plt.xlabel('GDP (current US$)')
plt.ylabel('Access to electricity (% of population)')
plt.title('Scatter Plot: GDP (current US$) vs Access to electricity (% of population)')

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Access to electricity (% of population)'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
result['GDP growth (annual %)']
# Out:
# code  Year  Access to electricity (% of population)
# ABW   2016  100.000000                                 1
#       2017  100.000000                                 1
#       2018  100.000000                                 1
#       2019  100.000000                                 1
#       2020  100.000000                                 1
#                                                       ..
# ZWE   2016  42.561730                                  1
#       2017  44.178635                                  1
#       2018  45.572647                                  1
#       2019  46.781475                                  1
#       2020  52.747670                                  1
# Name: GDP growth (annual %), Length: 1060, dtype: int64
